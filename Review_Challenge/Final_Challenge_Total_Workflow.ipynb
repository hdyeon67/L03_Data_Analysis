# %% [markdown]
# # [Final Challenge] TMDB 영화 데이터 분석 및 전략 보고서
#
# 이 노트북은 데이터 분석의 전 과정(**로드 - 정제 - 변환 - 상관분석 - 시계열분석 - 시각화**)을 하나의 흐름으로 경험하기 위해 설계되었습니다.
#
# ### 🎬 시나리오
# 당신은 영화 제작사 'Antigravity Studio'의 수석 데이터 분석가입니다.
# 회사는 차기작의 흥행을 위해 **TMDB 데이터**를 분석하여 최적의 개봉 시점과 장르, 그리고 예산 전략을 세우고자 합니다.
#
# ---

# %% [markdown]
# ### Step 0. 데이터 로드 (read_json)
# 제공된 `tmdb_movies.json` 파일을 Pandas 데이터프레임으로 불러오세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# 파일명: tmdb_movies.json (노트북과 같은 폴더에 위치)
# 코드를 작성하여 df에 저장하세요 (힌트: pd.read_json('tmdb_movies.json'))

# %% [markdown]
# ### Step 1. 데이터 점검 및 정제 (Cleaning)
#
# **문제:**
# 1. `genres`와 `production_countries` 컬럼에서 각각 **첫 번째 장르명**과 **국가 코드**를 추출하여 `main_genre`, `country_code` 컬럼을 만드세요.
# 2. `budget`이나 `revenue`가 0인 데이터는 흥행 분석에서 제외하기 위해 해당 행을 필터링하세요.
# 3. `vote_average`가 0인 데이터는 전체 평점의 평균으로 대체하세요.
# 4. `runtime`이 300분을 초과하는 이상치를 찾아 제거하세요.

# %%
# 코드를 작성하세요

# %% [markdown]
# ### Step 2. 상관분석 (Correlation)
#
# **문제:**
# 1. 수치형 데이터(`budget`, `revenue`, `popularity`, `vote_average`, `runtime`) 간의 상관계수를 계산하세요.
# 2. 계산된 상관계수를 **히트맵(Heatmap)**으로 시각화하여, 어떤 변수가 수익(`revenue`)과 가장 강한 관계가 있는지 서술하세요.

# %%
# 코드를 작성하세요

# %% [markdown]
# ### Step 3. 시계열 분석 (Time Series)
#
# **문제:**
# 1. `release_date`를 datetime 타입으로 변환하고 인덱스로 설정하세요.
# 2. 연도별(`AS` 또는 `Y`) 평균 수익(`revenue`)의 변화를 계산하고 선 그래프로 시각화하세요.
# 3. 최근 24개월 동안의 인기도(`popularity`)에 대해 **3개월 이동평균**을 계산하여 선 그래프로 그리세요.

# %%
# 코드를 작성하세요

# %% [markdown]
# ### Step 4. 심화 분석 및 시각화
#
# **문제:**
# 1. 수익률(`ROI = revenue / budget`)을 계산하고, 장르별로 평균 ROI가 가장 높은 TOP 3 장르를 막대 그래프로 그리세요.
# 2. 평점(`vote_average`)분포를 히스토그램으로 그리되, 평균선(Vline)을 추가하세요.

# %%
# 코드를 작성하세요

# %% [markdown]
# ### Step 5. 최종 리포트 및 전략 제안
# 당신은 분석가로서 경영진에게 어떤 장르와 어떤 예산 규모의 영화를, 연중 어느 시기에 개봉할 것을 추천하시겠습니까? 분석 근거를 바탕으로 의견을 적어주세요.

# %% [markdown]
# (여기에 리포트를 작성하세요)
