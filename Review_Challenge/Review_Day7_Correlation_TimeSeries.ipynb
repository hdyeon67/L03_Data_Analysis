# %% [markdown]
# # [Day 7] 상관분석 및 시계열 데이터 복습
#
# Day 7에서 학습한 수치형 데이터 간의 상관관계 분석(`corr`, `heatmap`)과 시계열 데이터 처리(`resample`, `rolling`)를 복습합니다.

# %% [markdown]
# ### Q0. 연습용 데이터프레임을 생성합니다. (실행만 하세요)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# 시계열 데이터 생성
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
data = {
    'date': dates,
    'sales': np.random.randint(100, 1000, 100),
    'visitors': np.random.randint(50, 500, 100),
    'temperature': np.random.uniform(20, 35, 100)
}
df = pd.DataFrame(data)

# 상관관계 주입 (visitors와 sales는 비례 관계)
df['sales'] = df['visitors'] * 2 + np.random.normal(0, 50, 100)
df.head()

# %% [markdown]
# ### Q1. 수치형 컬럼들 간의 상관계수를 계산하세요. (`corr()` 활용)

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. 위에서 계산한 상관계수를 히트맵(`sns.heatmap`)으로 시각화하세요. (수치 표시 포함)

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q3. 'date' 컬럼을 인덱스로 설정한 후, 주간(Weekly) 단위로 'sales'의 합계를 구하세요. (`resample` 활용)

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q4. 'sales' 컬럼의 7일 이동평균(7-day moving average)을 계산하여 'sales_7d_avg' 컬럼을 새로 만드세요. (`rolling` 활용)

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q5. 원본 데이터의 'sales'와 방금 만든 'sales_7d_avg'를 동시에 선 그래프로 그려 출력하세요.

# %%
# 코드를 입력하세요
