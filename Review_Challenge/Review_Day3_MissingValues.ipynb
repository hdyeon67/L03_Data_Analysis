# %% [markdown]
# # [Day 3] 결측치 처리 및 간단 시각화 복습
#
# Day 3에서 학습한 결측치(Null, NaN) 확인 및 처리 방법, 그리고 Pandas를 활용한 기초 시각화를 복습합니다.

# %% [markdown]
# ### Q0. 결측치가 포함된 연습용 데이터프레임을 생성합니다. (실행만 하세요)

# %%
import pandas as pd
import numpy as np

data = {
    'A': [1, 2, np.nan, 4, 12],
    'B': [np.nan, 1, 2, 3, 33],
    'C': [4, 5, 2, np.nan, 7],
    'D': [10, 20, 30, 40, 50]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Q1. 각 컬럼별로 결측치의 개수가 몇 개인지 확인하는 코드를 작성하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. 데이터프레임에서 결측치가 하나라도 있는 행을 모두 제거하고 그 결과를 `df_clean`에 저장하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q3. 원본 데이터프레임 `df`의 'A' 컬럼 결측치를 'A' 컬럼의 평균값으로 채우세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q4. 'D' 컬럼의 데이터를 사용하여 선 그래프(Line plot)를 그려보세요.

# %%
# 코드를 입력하세요 (hint: df['D'].plot())
