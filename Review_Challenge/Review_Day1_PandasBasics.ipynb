# %% [markdown]
# # [Day 1] Pandas 기초 복습
#
# Day 1에서 학습한 Pandas의 기초 개념(Series, DataFrame)과 생성 방법을 복습합니다.

# %% [markdown]
# ### Q1. Pandas 라이브러리를 `pd`라는 별칭으로 불러오세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. 다음 데이터를 사용하여 `df_store`라는 이름의 데이터프레임을 생성하세요.
#
# | 상품명 | 가격 | 재고 | 카테고리 |
# | :--- | :--- | :--- | :--- |
# | 사과 | 1500 | 50 | 과일 |
# | 배 | 2000 | 20 | 과일 |
# | 우유 | 2500 | 100 | 유제품 |
# | 감자칩 | 1200 | 80 | 과자 |

# %%
# 딕셔너리 형태로 데이터를 구성한 후 데이터프레임을 만드세요

# %% [markdown]
# ### Q3. 생성한 `df_store` 데이터프레임의 상위 2개 행만 출력하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q4. `df_store` 데이터프레임의 요약 정보(인덱스, 컬럼명, 데이터 타입 등)를 확인하는 코드를 작성하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q5. `df_store` 데이터프레임에서 '가격' 컬럼의 평균값을 계산하세요.

# %%
# 코드를 입력하세요
