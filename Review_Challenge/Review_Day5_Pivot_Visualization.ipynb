# %% [markdown]
# # [Day 5] 피벗 테이블 및 시각화 기초 복습
#
# Day 5에서 학습한 `pivot_table`과 Matplotlib 라이브러리를 활용한 기본 그래프 작성을 복습합니다.

# %% [markdown]
# ### Q0. 연습용 데이터프레임을 생성합니다. (실행만 하세요)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Date': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02', '2024-01-01', '2024-01-02'],
    'User': ['Kim', 'Lee', 'Kim', 'Lee', 'Choi', 'Choi'],
    'Sales': [100, 200, 150, 300, 120, 250],
    'Region': ['Seoul', 'Seoul', 'Seoul', 'Seoul', 'Busan', 'Busan']
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Q1. `pivot_table`을 사용하여 'Date'를 행(Index)으로, 'Region'을 열(Column)로 하고 'Sales'의 합계를 집계하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. `pivot_table`을 사용하여 'Region'별 'Sales'의 평균값을 구하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q3. Matplotlib을 사용하여 x축은 [1, 2, 3, 4], y축은 [10, 20, 25, 30]인 선 그래프를 그리고 제목을 'Sample Chart'로 설정하세요.

# %%
# 코드를 입력하세요
# plt.plot(...)
# plt.title(...)
# plt.show()
