# %% [markdown]
# # [Day 4] 이상치 처리 및 데이터 요약(Groupby) 복습
#
# Day 4에서 학습한 이상치(Outlier)를 판별하는 방법(Boxplot, IQR)과 데이터를 그룹별로 집계하는 `groupby`를 복습합니다.

# %% [markdown]
# ### Q0. 연습용 데이터프레임을 생성합니다. (실행만 하세요)

# %%
import pandas as pd

data = {
    'Team': ['A', 'A', 'B', 'B', 'C', 'C', 'A', 'B'],
    'Points': [10, 15, 10, 20, 30, 40, 50, 60],
    'Assists': [5, 7, 7, 8, 12, 9, 100, 10]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Q1. 'Assists' 컬럼에서 이상치가 있는지 확인하기 위해 박스 플롯(Boxplot)을 그려보세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. 'Team'별로 그룹화하여 'Points'의 합계를 구하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q3. 'Team'별로 그룹화하여 'Points'와 'Assists'의 평균값을 모두 구하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q4. 'Assists' 컬럼에서 50보다 큰 값을 가진 행을 제거하여 이상치를 처리한 결과를 `df_filtered`에 저장하세요.

# %%
# 코드를 입력하세요
