# %% [markdown]
# # [Day 6] Seaborn 실전 시각화 복습
#
# Day 6에서 학습한 Seaborn 라이브러리를 활용한 다양한 그래프 작성과 스타일 설정을 복습합니다.

# %% [markdown]
# ### Q0. 필요한 라이브러리를 불러오고 예제 데이터를 준비합니다. (실행만 하세요)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Seaborn에 내장된 'tips' 데이터를 사용합니다.
tips = sns.load_dataset('tips')
tips.head()

# %% [markdown]
# ### Q1. 'total_bill'과 'tip'의 관계를 보여주는 산점도(Scatter plot)를 그리세요.
#
# - 힌트: `sns.scatterplot(data=tips, x='...', y='...')`

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. 요일('day')별로 'total_bill'의 평균을 보여주는 막대 그래프(Bar plot)를 그리세요.
#
# - 힌트: `sns.barplot(...)`

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q3. 식사 시간대('time')에 따른 'total_bill'의 분포를 박스 플롯(Box plot)으로 그리세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q4. 성별('sex')을 색상(hue)으로 구분하여 'total_bill'과 'tip'의 산점도를 그리세요.

# %%
# 코드를 입력하세요
