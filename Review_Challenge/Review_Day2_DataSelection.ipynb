# %% [markdown]
# # [Day 2] 데이터 선택 및 필터링 복습
#
# Day 2에서 학습한 컬럼/행 선택 방법과 loc, iloc, 그리고 조건부 필터링(Boolean Indexing)을 복습합니다.

# %% [markdown]
# ### Q0. 연습용 데이터프레임을 생성합니다. (실행만 하세요)

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 32, 18, 45, 29],
    'City': ['New York', 'Paris', 'London', 'Berlin', 'Tokyo'],
    'Score': [85, 92, 78, 88, 95]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Q1. 'Name'과 'Score' 컬럼만 선택하여 출력하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q2. `loc`를 사용하여 'Charlie'의 'City' 정보를 가져오세요. (인덱스 번호 2번 사용)

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q3. `iloc`를 사용하여 마지막 행의 데이터를 출력하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q4. 'Age'가 30세 이상인 데이터만 필터링하여 출력하세요.

# %%
# 코드를 입력하세요

# %% [markdown]
# ### Q5. 'Score'가 80점 이상이면서 'City'가 'Tokyo'인 데이터를 필터링하세요.

# %%
# 코드를 입력하세요
